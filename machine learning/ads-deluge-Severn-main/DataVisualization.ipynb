# %% [markdown]
# # Data Visualization
#
# ## Placholder Notebook
#
# This notebook allows you to quickly start examining your data, expect it to change a lot over the course of the week.
#
# ### Postcode data

# %%
import pandas as pd

# The unlabelled postcode data
df1 = pd.read_csv('./flood_tool/resources/postcodes_unlabelled.csv')
df1.head()
# Out:
#    postcode  sector   easting  northing    localAuthority
# 0  YO62 4LS  YO62 4  467631.0  472825.0           Ryedale
# 1   DE2 3DA   DE2 3  434011.0  330722.0  South Derbyshire
# 2   LN5 7RW   LN5 7  497441.0  370798.0           Lincoln
# 3   CM3 1DW   CM3 1  571061.0  207179.0        Chelmsford
# 4  CH60 0WA  CH60 0  326913.0  381988.0            Wirral

# %%
# The labelled postcode data

df2 = pd.read_csv('./flood_tool/resources/postcodes_sampled.csv')
df2.head()
# Out:
#    postcode  sector   easting  northing localAuthority  riskLabel  medianPrice
# 0   GU1 4XF   GU1 4  499691.0  149942.0      Guildford          1    1253800.0
# 1  TN13 2JB  TN13 2  552025.0  155534.0      Sevenoaks          1     728200.0
# 2    S7 2BD    S7 2  434300.0  384300.0      Sheffield          1     327400.0
# 3   PR1 5LT   PR1 5  354912.0  429855.0        Preston          1     105600.0
# 4   WR4 9NJ   WR4 9  386834.0  256972.0      Worcester          1     262800.0

# %%
# The data on number of households

df3 = pd.read_csv('./flood_tool/resources/households_per_sector.csv')
df3.head()
# Out:
#   postcode sector  households  number of postcode units
# 0          AL1  1        2546                       311
# 1          AL1  2        2642                       236
# 2          AL1  3        2272                       388
# 3          AL1  4        3707                       339
# 4          AL1  5        4406                       347

# %%
# The data on measurement stations

df4 = pd.read_csv('./flood_tool/resources/stations.csv')
df4.tail()
# Out:
#             Unnamed: 0       stationName   latitude  longitude
# 1980             L3211            Hessle  53.719075  -0.434087
# 1981            Mitch1  Rainfall station  53.742978  -2.323663
# 1982    PCHURCH_TG_342       Peterchurch  52.041372  -2.955501
# 1983             SE730        LENSIDE GS  51.272544   0.525902
# 1984  VCHURCH-T_TG_341  Rainfall station  52.023749  -2.921750

# %%
# The data for a wet day

df5 = pd.read_csv('./flood_tool/resources/wet_day.csv')
df5.head()
# Out:
# C:\Users\origi\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                dateTime stationReference parameter                 qualifier  \
# 0  2021-05-07T00:00:00Z            E5726  rainfall  Tipping Bucket Raingauge
# 1  2021-05-07T00:00:00Z            48155  rainfall  Tipping Bucket Raingauge
# 2  2021-05-07T00:00:00Z            48105  rainfall  Tipping Bucket Raingauge
# 3  2021-05-07T00:00:00Z           2927TH     level                     Stage
# 4  2021-05-07T00:00:00Z           0710TH     level                     Stage
#
#   unitName  value
# 0       mm  0.000
# 1       mm  0.000
# 2       mm  0.000
# 3     mASD  0.795
# 4     mASD  1.964

# %%
# The data for a more typical day

df5 = pd.read_csv('./flood_tool/resources/typical_day.csv')
df5.head()
# Out:
#                dateTime stationReference parameter                 qualifier  \
# 0  2021-10-10T00:00:00Z            E5726  rainfall  Tipping Bucket Raingauge
# 1  2021-10-10T00:00:00Z             2206     level                     Stage
# 2  2021-10-10T00:00:00Z           2431TH     level                     Stage
# 3  2021-10-10T00:00:00Z           E24632  rainfall  Tipping Bucket Raingauge
# 4  2021-10-10T00:00:00Z             2107     level                     Stage
#
#   unitName  value
# 0       mm  0.000
# 1     mASD  0.000
# 2     mASD  1.358
# 3       mm  0.000
# 4     mASD  0.662

# %% [markdown]
# ### Mapping your data
#
# As one possible approach, we have provided a function to plot a circle on a map using the `folium` package. You can use `folium` and expand on this functionality, or you may prefer to use a different package. Please check with us that the mapping package you wish to use is permissible before you start.

# %%
import folium
import flood_tool
map = flood_tool.plot_circle(53., 0, 2000.) #Plots a circle of radius 2000 m at the lat, lon: 53., 0.

folium.Marker(location=(53, 0.1), 
                  popup='This is my popup',
                  icon=folium.Icon(color='black', icon='info-sign')).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
